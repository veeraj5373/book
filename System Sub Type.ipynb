# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler,OneHotEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras import models, layers, optimizers, regularizers
from sklearn import model_selection, preprocessing
import tensorflow as tf
from tensorflow. keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical

# %%
dataframe = pd.read_excel('book2.xlsx')
dataframe=dataframe.drop("Incident Date" , axis='columns')

# %%
print(dataframe.nunique())
print(dataframe.info())
dataframe
# Out:
# Calendar Year                       20
# Portal Year                          1
# Report ID                         1512
# State Name                          48
# State Abbreviation                  48
# Incident County                    659
# Operator Business Name             319
# Operator ID                        319
# Incident Cause Type                  1
# Incident Cause SubType              23
# Serious Incident Flag                2
# Significant Incident Flag            1
# # of Fatalities                      4
# # of Injuries                        9
# Total Property Damage             1537
# # of Incidents                       1
# Total Property Damage-Cur Yr $    1631
# Commodity Spilled Amount bbls      495
# Net Spill bbls                     349
# System Sub Type                      6
# Serious Incident Flag.1              2
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Calendar Year                   1801 non-null   int64
#  1   Portal Year                     1801 non-null   object
#  2   Report ID                       1801 non-null   int64
#  3   State Name                      1800 non-null   object
#  4   State Abbreviation              1800 non-null   object
#  5   Incident County                 1720 non-null   object
#  6   Operator Business Name          1801 non-null   object
#  7   Operator ID                     1801 non-null   int64
#  8   Incident Cause Type             1801 non-null   object
#  9   Incident Cause SubType          1801 non-null   object
#  10  Serious Incident Flag           1801 non-null   object
#  11  Significant Incident Flag       1801 non-null   object
#  12  # of Fatalities                 1801 non-null   int64
#  13  # of Injuries                   1801 non-null   int64
#  14  Total Property Damage           1801 non-null   int64
#  15  # of Incidents                  1801 non-null   int64
#  16  Total Property Damage-Cur Yr $  1801 non-null   float64
#  17  Commodity Spilled Amount bbls   1801 non-null   float64
#  18  Net Spill bbls                  1801 non-null   float64
#  19  System Sub Type                 1801 non-null   object
#  20  Serious Incident Flag.1         1801 non-null   object
# dtypes: float64(3), int64(7), object(11)
# memory usage: 295.6+ KB
# None
#       Calendar Year Portal Year  Report ID      State Name State Abbreviation  \
# 0              2003    18/08/23   20030148           TEXAS                 TX
# 1              2003    18/08/23   20030225           TEXAS                 TX
# 2              2003    18/08/23   20030347         MONTANA                 MT
# 3              2003    18/08/23   20030275           TEXAS                 TX
# 4              2003    18/08/23   20030290     MISSISSIPPI                 MS
# ...             ...         ...        ...             ...                ...
# 1796           2022    18/08/23   20220029         ALABAMA                 AL
# 1797           2022    18/08/23   20220081  NORTH CAROLINA                 NC
# 1798           2022    18/08/23   20220054         ALABAMA                 AL
# 1799           2022    18/08/23   20220172        OKLAHOMA                 OK
# 1800           2022    18/08/23   20230014        NEW YORK                 NY
#
#      Incident County                  Operator Business Name  Operator ID  \
# 0         HUTCHINSON                  NUSTAR LOGISTICS, L.P.        31454
# 1          JIM WELLS               FLINT HILLS RESOURCES, LC        22855
# 2             CARTER               BELLE FOURCHE PIPELINE CO         1248
# 3            LIBERTY               MOBIL  PIPE  LINE COMPANY        12628
# 4            HANCOCK                    COLONIAL PIPELINE CO         2552
# ...              ...                                     ...          ...
# 1796           PERRY                 SOUTHERN NATURAL GAS CO        18516
# 1797           MOORE              DIXIE PIPELINE COMPANY LLC         3445
# 1798         MARENGO  TRANSCONTINENTAL GAS PIPE LINE COMPANY        19570
# 1799           PAYNE            OSAGE PIPE LINE COMPANY, LLC        14391
# 1800          PUTMAN      NEW YORK STATE ELECTRIC & GAS CORP        13420
#
#               Incident Cause Type                 Incident Cause SubType  ...  \
# 0     MATERIAL/WELD/EQUIP FAILURE  RUPTURED OR LEAKING SEAL/PUMP PACKING  ...
# 1     MATERIAL/WELD/EQUIP FAILURE  RUPTURED OR LEAKING SEAL/PUMP PACKING  ...
# 2     MATERIAL/WELD/EQUIP FAILURE  RUPTURED OR LEAKING SEAL/PUMP PACKING  ...
# 3     MATERIAL/WELD/EQUIP FAILURE  RUPTURED OR LEAKING SEAL/PUMP PACKING  ...
# 4     MATERIAL/WELD/EQUIP FAILURE  RUPTURED OR LEAKING SEAL/PUMP PACKING  ...
# ...                           ...                                    ...  ...
# 1796  MATERIAL/WELD/EQUIP FAILURE                  MANUFACTURING-RELATED  ...
# 1797  MATERIAL/WELD/EQUIP FAILURE                  MANUFACTURING-RELATED  ...
# 1798  MATERIAL/WELD/EQUIP FAILURE                  MANUFACTURING-RELATED  ...
# 1799  MATERIAL/WELD/EQUIP FAILURE                  MANUFACTURING-RELATED  ...
# 1800  MATERIAL/WELD/EQUIP FAILURE               MECHANICAL JOINT FAILURE  ...
#
#      Significant Incident Flag # of Fatalities  # of Injuries  \
# 0                          Yes               0              0
# 1                          Yes               0              0
# 2                          Yes               0              0
# 3                          Yes               0              0
# 4                          Yes               0              0
# ...                        ...             ...            ...
# 1796                       Yes               0              0
# 1797                       Yes               0              0
# 1798                       Yes               0              0
# 1799                       Yes               0              0
# 1800                       Yes               0              0
#
#       Total Property Damage  # of Incidents  Total Property Damage-Cur Yr $  \
# 0                      9500               1                    1.433047e+04
# 1                     76801               1                    1.158520e+05
# 2                      6500               1                    9.805058e+03
# 3                       410               1                    6.184729e+02
# 4                    213125               1                    3.214928e+05
# ...                     ...             ...                             ...
# 1796                1265788               1                    1.274939e+06
# 1797                 732000               1                    7.479600e+05
# 1798                5617741               1                    5.734672e+06
# 1799               36985428               1                    3.779183e+07
# 1800                 430137               1                    4.395146e+05
#
#       Commodity Spilled Amount bbls  Net Spill bbls   System Sub Type  \
# 0                        362.000000       12.000000  HAZARDOUS LIQUID
# 1                        100.000000       90.000000  HAZARDOUS LIQUID
# 2                        120.000000        5.000000  HAZARDOUS LIQUID
# 3                         13.000000       13.000000  HAZARDOUS LIQUID
# 4                          0.071429        0.071429  HAZARDOUS LIQUID
# ...                             ...             ...               ...
# 1796                       0.000000        0.000000  GAS TRANSMISSION
# 1797                       8.800000        8.800000  HAZARDOUS LIQUID
# 1798                       0.000000        0.000000  GAS TRANSMISSION
# 1799                    7110.000000      542.880000  HAZARDOUS LIQUID
# 1800                       0.000000        0.000000  GAS DISTRIBUTION
#
#      Serious Incident Flag.1
# 0                         No
# 1                         No
# 2                         No
# 3                         No
# 4                         No
# ...                      ...
# 1796                      No
# 1797                      No
# 1798                      No
# 1799                      No
# 1800                      No
#
# [1801 rows x 21 columns]

# %%
dataframe=dataframe.drop('Portal Year' , axis='columns')
dataframe=dataframe.drop('Report ID', axis='columns')
dataframe=dataframe.drop('Incident Cause Type', axis='columns')
dataframe=dataframe.drop('# of Incidents', axis='columns')
dataframe=dataframe.drop('State Name', axis='columns')
dataframe=dataframe.drop('Significant Incident Flag', axis='columns')
dataframe=dataframe.drop('Serious Incident Flag.1', axis='columns')
dataframe=dataframe.drop('Total Property Damage-Cur Yr $', axis='columns')
dataframe=dataframe.drop('Operator Business Name', axis='columns')

# %%
column_to_move = "Serious Incident Flag"

# Get the column and remove it from its current position
column = dataframe.pop(column_to_move)

# Insert the column at the last position
dataframe.insert(dataframe.shape[1], column_to_move, column)

# %%
for column in dataframe.columns:
    plt.figure()
    if dataframe[column].dtype == 'object':
        
        dataframe[column].value_counts().plot(kind='bar')
        plt.title(f'Bar Plot for {column}')
    else:
        
        dataframe[column].plot(kind='hist', bins=30)  
        plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
for column in dataframe.columns:
    if dataframe[column].dtype == 'object':
        print(column)
# Out:
# State Abbreviation
# Incident County
# Incident Cause SubType
# System Sub Type
# Serious Incident Flag

# %%
country=LabelEncoder()
for column in dataframe.columns:
    if dataframe[column].dtype == 'object':
        dataframe[column]=country.fit_transform (dataframe[column])

# %%
dataframe
# Out:
#       Calendar Year  State Abbreviation  Incident County  Operator ID  \
# 0              2003                  41              286        31454
# 1              2003                  41              302        22855
# 2              2003                  23               97         1248
# 3              2003                  41              351        12628
# 4              2003                  22              255         2552
# ...             ...                 ...              ...          ...
# 1796           2022                   1              472        18516
# 1797           2022                  24              419         3445
# 1798           2022                   1              380        19570
# 1799           2022                  34              466        14391
# 1800           2022                  30              499        13420
#
#       Incident Cause SubType  # of Fatalities  # of Injuries  \
# 0                         17                0              0
# 1                         17                0              0
# 2                         17                0              0
# 3                         17                0              0
# 4                         17                0              0
# ...                      ...              ...            ...
# 1796                      10                0              0
# 1797                      10                0              0
# 1798                      10                0              0
# 1799                      10                0              0
# 1800                      11                0              0
#
#       Total Property Damage  Commodity Spilled Amount bbls  Net Spill bbls  \
# 0                      9500                     362.000000       12.000000
# 1                     76801                     100.000000       90.000000
# 2                      6500                     120.000000        5.000000
# 3                       410                      13.000000       13.000000
# 4                    213125                       0.071429        0.071429
# ...                     ...                            ...             ...
# 1796                1265788                       0.000000        0.000000
# 1797                 732000                       8.800000        8.800000
# 1798                5617741                       0.000000        0.000000
# 1799               36985428                    7110.000000      542.880000
# 1800                 430137                       0.000000        0.000000
#
#       System Sub Type  Serious Incident Flag
# 0                   3                      0
# 1                   3                      0
# 2                   3                      0
# 3                   3                      0
# 4                   3                      0
# ...               ...                    ...
# 1796                2                      0
# 1797                3                      0
# 1798                2                      0
# 1799                3                      0
# 1800                0                      0
#
# [1801 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(11,7))
sns.heatmap(dataframe.corr(), annot=True, cmap='coolwarm', linewidths=0.5)

plt.show()

# %%
z_score_scaler = StandardScaler()
selected_columns = [col for col in dataframe.columns if dataframe[col].nunique() > 1]


dataframe_standardized = pd.DataFrame(z_score_scaler.fit_transform(dataframe[selected_columns]), columns=selected_columns)

# %%
fig, ax = plt.subplots(figsize=(11,7))
sns.heatmap(dataframe_standardized.corr(), annot=True, cmap='coolwarm', linewidths=0.5)

plt.show()

# %%
for column in dataframe_standardized.columns:
    plt.figure()
    if dataframe_standardized[column].nunique() <= 10:
        
        dataframe_standardized[column].value_counts().plot(kind='bar')
        plt.title(f'Bar Plot for {column}')
    else:
        
        dataframe_standardized[column].plot(kind='hist', bins=20)  
        plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
given_column = 'System Sub Type'

# Calculate the correlation matrix
correlation_matrix = dataframe_standardized.corr()

# Get the absolute values of the correlation with the given column
correlation_with_given_column = correlation_matrix[given_column].abs()

# Sort the columns based on the correlation values and select the top 5
top_5_columns = correlation_with_given_column.sort_values(ascending=False).head(6).index[1:]

# Display the top 5 columns
print("Top 5 columns based on correlation with", given_column, ":", top_5_columns)

# Select the columns in the original DataFrame
selected_columns = dataframe_standardized[top_5_columns]

# Display the DataFrame with the selected columns
print(selected_columns)
# Out:
# Top 5 columns based on correlation with System Sub Type : Index(['Serious Incident Flag', 'Operator ID', 'Incident Cause SubType',
#        '# of Injuries', 'Commodity Spilled Amount bbls'],
#       dtype='object')
#       Serious Incident Flag  Operator ID  Incident Cause SubType  \
# 0                   -0.2099     0.941734                1.367022
# 1                   -0.2099     0.222835                1.367022
# 2                   -0.2099    -1.583567                1.367022
# 3                   -0.2099    -0.632170                1.367022
# 4                   -0.2099    -1.474550                1.367022
# ...                     ...          ...                     ...
# 1796                -0.2099    -0.139917                0.071716
# 1797                -0.2099    -1.399892                0.071716
# 1798                -0.2099    -0.051800                0.071716
# 1799                -0.2099    -0.484778                0.071716
# 1800                -0.2099    -0.565956                0.256760
#
#       # of Injuries  Commodity Spilled Amount bbls
# 0         -0.071971                      -0.022534
# 1         -0.071971                      -0.130468
# 2         -0.071971                      -0.122228
# 3         -0.071971                      -0.166308
# 4         -0.071971                      -0.171634
# ...             ...                            ...
# 1796      -0.071971                      -0.171664
# 1797      -0.071971                      -0.168038
# 1798      -0.071971                      -0.171664
# 1799      -0.071971                       2.757374
# 1800      -0.071971                      -0.171664
#
# [1801 rows x 5 columns]

# %%
x=selected_columns
y=dataframe_standardized['System Sub Type']
y = to_categorical(y, num_classes=6)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [raw]
# CREATE A SEQUENTIAL MODEL

# %% [raw]
# OUTPUT:['System Sub Type']
# INPUT:['Serious Incident Flag', 'Operator ID', 'Incident CauseSubType','# of Injuries', 'Commodity Spilled Amount bbls']

# %%
# create a sequential model
model = models.Sequential()
# add the hidden layer
model.add(layers.Dense(input_dim=5,
                       units=15, 
                       activation='relu'))

# add the output layer
model.add(layers.Dense(
                       units=6,
                       activation='softmax'))

# define our loss function and optimizer
model.compile(loss='categorical_crossentropy',
              # Adam is a kind of gradient descent
              optimizer=optimizers.Adam(lr=0.001),
              metrics=['accuracy'])


# train the parameters
history = model.fit(x_train, y_train, epochs=50, batch_size=32)

# evaluate accuracy
train_acc = model.evaluate(x_train, y_train, batch_size=32)[1]
test_acc = model.evaluate(x_test, y_test, batch_size=32)[1]
print('Training accuracy: %s' % train_acc)
print('Testing accuracy: %s' % test_acc)

losses = history.history['loss']
plt.plot(range(len(losses)), losses, 'r')
plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 40/40 [==============================] - 0s 381us/step - loss: 2.0381 - accuracy: 0.1032
# Epoch 2/50
# 40/40 [==============================] - 0s 327us/step - loss: 1.6832 - accuracy: 0.3325
# Epoch 3/50
# 40/40 [==============================] - 0s 314us/step - loss: 1.3807 - accuracy: 0.5921
# Epoch 4/50
# 40/40 [==============================] - 0s 303us/step - loss: 1.1209 - accuracy: 0.8706
# Epoch 5/50
# 40/40 [==============================] - 0s 295us/step - loss: 0.9061 - accuracy: 0.8905
# Epoch 6/50
# 40/40 [==============================] - 0s 292us/step - loss: 0.7347 - accuracy: 0.8968
# Epoch 7/50
# 40/40 [==============================] - 0s 308us/step - loss: 0.6058 - accuracy: 0.8984
# Epoch 8/50
# 40/40 [==============================] - 0s 302us/step - loss: 0.5161 - accuracy: 0.9024
# Epoch 9/50
# 40/40 [==============================] - 0s 303us/step - loss: 0.4564 - accuracy: 0.9056
# Epoch 10/50
# 40/40 [==============================] - 0s 282us/step - loss: 0.4174 - accuracy: 0.9071
# Epoch 11/50
# 40/40 [==============================] - 0s 300us/step - loss: 0.3923 - accuracy: 0.9111
# Epoch 12/50
# 40/40 [==============================] - 0s 306us/step - loss: 0.3746 - accuracy: 0.9167
# Epoch 13/50
# 40/40 [==============================] - 0s 298us/step - loss: 0.3628 - accuracy: 0.9167
# Epoch 14/50
# 40/40 [==============================] - 0s 286us/step - loss: 0.3539 - accuracy: 0.9190
# Epoch 15/50
# 40/40 [==============================] - 0s 281us/step - loss: 0.3472 - accuracy: 0.9198
# Epoch 16/50
# 40/40 [==============================] - 0s 300us/step - loss: 0.3422 - accuracy: 0.9222
# Epoch 17/50
# 40/40 [==============================] - 0s 305us/step - loss: 0.3378 - accuracy: 0.9222
# Epoch 18/50
# 40/40 [==============================] - 0s 310us/step - loss: 0.3344 - accuracy: 0.9222
# Epoch 19/50
# 40/40 [==============================] - 0s 288us/step - loss: 0.3319 - accuracy: 0.9222
# Epoch 20/50
# 40/40 [==============================] - 0s 299us/step - loss: 0.3295 - accuracy: 0.9222
# Epoch 21/50
# 40/40 [==============================] - 0s 310us/step - loss: 0.3277 - accuracy: 0.9222
# Epoch 22/50
# 40/40 [==============================] - 0s 301us/step - loss: 0.3260 - accuracy: 0.9222
# Epoch 23/50
# 40/40 [==============================] - 0s 291us/step - loss: 0.3241 - accuracy: 0.9222
# Epoch 24/50
# 40/40 [==============================] - 0s 293us/step - loss: 0.3227 - accuracy: 0.9222
# Epoch 25/50
# 40/40 [==============================] - 0s 312us/step - loss: 0.3216 - accuracy: 0.9222
# Epoch 26/50
# 40/40 [==============================] - 0s 303us/step - loss: 0.3202 - accuracy: 0.9222
# Epoch 27/50
# 40/40 [==============================] - 0s 305us/step - loss: 0.3191 - accuracy: 0.9222
# Epoch 28/50
# 40/40 [==============================] - 0s 294us/step - loss: 0.3180 - accuracy: 0.9222
# Epoch 29/50
# 40/40 [==============================] - 0s 302us/step - loss: 0.3173 - accuracy: 0.9222
# Epoch 30/50
# 40/40 [==============================] - 0s 331us/step - loss: 0.3164 - accuracy: 0.9230
# Epoch 31/50
# 40/40 [==============================] - 0s 330us/step - loss: 0.3157 - accuracy: 0.9230
# Epoch 32/50
# 40/40 [==============================] - 0s 303us/step - loss: 0.3147 - accuracy: 0.9222
# Epoch 33/50
# 40/40 [==============================] - 0s 316us/step - loss: 0.3141 - accuracy: 0.9222
# Epoch 34/50
# 40/40 [==============================] - 0s 316us/step - loss: 0.3138 - accuracy: 0.9206
# Epoch 35/50
# 40/40 [==============================] - 0s 302us/step - loss: 0.3129 - accuracy: 0.9230
# Epoch 36/50
# 40/40 [==============================] - 0s 341us/step - loss: 0.3123 - accuracy: 0.9230
# Epoch 37/50
# 40/40 [==============================] - 0s 327us/step - loss: 0.3120 - accuracy: 0.9230
# Epoch 38/50
# 40/40 [==============================] - 0s 300us/step - loss: 0.3113 - accuracy: 0.9230
# Epoch 39/50
# 40/40 [==============================] - 0s 306us/step - loss: 0.3109 - accuracy: 0.9230
# Epoch 40/50
# 40/40 [==============================] - 0s 302us/step - loss: 0.3103 - accuracy: 0.9230
# Epoch 41/50
# 40/40 [==============================] - 0s 337us/step - loss: 0.3100 - accuracy: 0.9230
# Epoch 42/50
# 40/40 [==============================] - 0s 327us/step - loss: 0.3094 - accuracy: 0.9230
# Epoch 43/50
# 40/40 [==============================] - 0s 320us/step - loss: 0.3091 - accuracy: 0.9230
# Epoch 44/50
# 40/40 [==============================] - 0s 313us/step - loss: 0.3087 - accuracy: 0.9238
# Epoch 45/50
# 40/40 [==============================] - 0s 313us/step - loss: 0.3083 - accuracy: 0.9230
# Epoch 46/50
# 40/40 [==============================] - 0s 337us/step - loss: 0.3083 - accuracy: 0.9230
# Epoch 47/50
# 40/40 [==============================] - 0s 331us/step - loss: 0.3076 - accuracy: 0.9230
# Epoch 48/50
# 40/40 [==============================] - 0s 335us/step - loss: 0.3073 - accuracy: 0.9230
# Epoch 49/50
# 40/40 [==============================] - 0s 340us/step - loss: 0.3067 - accuracy: 0.9230
# Epoch 50/50
# 40/40 [==============================] - 0s 316us/step - loss: 0.3066 - accuracy: 0.9238
# 40/40 [==============================] - 0s 326us/step - loss: 0.3059 - accuracy: 0.9238
# 17/17 [==============================] - 0s 332us/step - loss: 0.3538 - accuracy: 0.9205
# Training accuracy: 0.9238095283508301
# Testing accuracy: 0.9205175638198853

# %%
model.evaluate(x_test, y_test)
# Out:
# 17/17 [==============================] - 0s 444us/step - loss: 0.3538 - accuracy: 0.9205
# [0.3537905812263489, 0.9205175638198853]

# %%
model.summary()
for layer in model.layers:
    if layer.trainable:
        print(f"Weights of {layer.name}: {layer.get_weights()}")
# Out:
# Model: "sequential_76"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_163 (Dense)           (None, 15)                90
#
#  dense_164 (Dense)           (None, 6)                 96
#
# =================================================================
# Total params: 186
# Trainable params: 186
# Non-trainable params: 0
# _________________________________________________________________
# Weights of dense_163: [array([[ 0.37750822,  0.83930826, -0.77578205, -0.7915117 , -0.05935573,
#          0.40071008, -0.38949466,  0.22457962, -0.1927282 , -0.3310193 ,
#         -0.1536991 , -0.01073774,  0.24945189, -0.11171677,  0.01554201],
#        [ 0.14822589, -0.8028465 , -0.62074775, -0.5289034 , -0.03636966,
#         -0.83610326,  0.5904191 , -0.33049324, -0.25027063,  0.5733875 ,
#          0.09519576,  1.0720294 ,  0.22667982,  0.17088978,  0.31815392],
#        [-0.32254905,  0.25719166, -0.4515587 , -0.74727124, -0.17133106,
#          0.70400125, -0.4107818 ,  0.05132533,  0.30400407,  0.24832919,
#          0.01542955,  0.6739793 , -0.04526567,  0.13743265,  0.69274855],
#        [-0.07347026, -0.0044875 ,  0.37435785, -1.2923974 , -0.01205793,
#          0.18260463, -0.94033194,  0.46031034,  0.45297745, -0.36497128,
#         -0.10517082, -0.7229277 , -0.22439684,  0.24260661, -0.36857015],
#        [-0.18981948,  0.13992462,  0.17696503, -0.773546  ,  0.06165396,
#         -0.32197425,  0.4642341 ,  0.34112045, -0.23985536,  0.14282049,
#          0.3785156 ,  0.39644286,  0.30068922,  0.2804595 ,  0.28216702]],
#       dtype=float32), array([-0.07786141,  0.50642556,  0.37457862,  0.7477349 , -0.14920066,
#         0.4281089 ,  0.5039422 , -0.14851457, -0.21660158,  0.03959861,
#        -0.12032103,  0.77212346, -0.20971623, -0.20131133,  0.51160735],
#       dtype=float32)]
# Weights of dense_164: [array([[ 0.05506401, -0.02845361, -0.2820924 ,  0.1309299 ,  0.40865457,
#          0.1250003 ],
#        [ 0.3217265 , -0.25953212, -0.35004342, -0.17795423,  0.6015242 ,
#          0.05068367],
#        [ 0.84455705, -0.52617806, -0.8032156 , -0.579063  , -0.37767783,
#          0.03715863],
#        [ 0.52993757, -0.08691654, -0.1632492 , -1.0872114 ,  0.41499346,
#          0.04181981],
#        [-0.307964  , -0.4540514 ,  0.03545513, -0.47517243, -0.24511342,
#         -0.72053915],
#        [ 0.57380056, -0.7393423 , -0.0769389 , -0.5110334 ,  0.5884647 ,
#         -0.58407235],
#        [ 0.88967055, -0.6829925 , -0.7391391 , -0.11133169,  0.03926069,
#         -0.6743844 ],
#        [-0.19182064, -0.6294946 ,  0.07212912, -0.7692969 , -0.22355717,
#         -0.4347174 ],
#        [-0.27511096, -0.45600682,  0.26616454, -0.4942183 , -0.22045857,
#         -0.22826624],
#        [ 0.09913938,  0.30925485, -0.13248555, -0.5684466 , -0.35106194,
#         -0.6061334 ],
#        [ 0.21100354, -0.45367074,  0.31956896,  0.02249171,  0.19909039,
#          0.16888605],
#        [ 0.2189031 , -0.7503038 , -1.0547731 , -0.9497525 , -0.51068884,
#          0.00806515],
#        [-0.15067038, -0.00711909,  0.29159635, -0.43282035, -0.19245021,
#         -0.6971207 ],
#        [-0.2519807 ,  0.2155864 , -0.5672236 ,  0.22550744, -0.06239677,
#          0.3341153 ],
#        [ 0.43864772, -0.42447874, -0.36617205, -0.98036593, -0.39444888,
#          0.18419787]], dtype=float32), array([ 0.31193796, -0.30826187, -0.38262567, -0.3812402 , -0.20989153,
#        -0.26457265], dtype=float32)]
